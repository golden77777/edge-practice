# %% [markdown]
# ## 必要なライブラリの読み込み

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from IPython.display import Image

# %% [markdown]
# ## 今回取り扱う画像の表示

# %%
Image("test2.png", width = 400, height = 200)

# %% [markdown]
# ## Cannyアルゴリズムによるエッジ検出結果

# %%
img = cv2.imread('test2.png',0)
edges = cv2.Canny(img,100,200)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# ## ラプラシアンによるエッジ検出結果

# %%
img2 = cv2.imread('test2.png',0)
edges = cv2.Laplacian(img2, cv2.CV_32F)

plt.subplot(121),plt.imshow(img2,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# ## Sobelアルゴリズムによるエッジ検出結果

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img3 = cv2.imread('test2.png',0)
edges = cv2.Sobel(img3, cv2.CV_32F, 1, 0, ksize=3)

plt.subplot(121),plt.imshow(img3,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()
